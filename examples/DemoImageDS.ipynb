# %%
# %load_ext autoreload
# %autoreload 2
from dtoolbioimage import ImageDataSet

# %%
ids = ImageDataSet('https://jicscratch.blob.core.windows.net/9ba59d95-4a1c-46b6-8105-441fa94eb6a6')

# %%
ids.get_image_names()

# %%
ids.get_series_names('050218_WT_tapetum_protoplasts_Hoechst_GFP')

# %%
stack = ids.get_stack('050218_WT_tapetum_protoplasts_Hoechst_GFP', 'Series001', 0)

# %%
stack
# Out:
# Image3D([[[ 14,   6,  10, ...,  16,  26,  16],
#           [  8,   8,   4, ...,   8,  16,   8],
#           [ 16,   6,   8, ...,  12,  14,  12],
#           ...,
#           [ 64,  79,  64, ...,  87,  77,  98],
#           [ 56,  92,  83, ...,  96,  58,  81],
#           [ 77,  75,  69, ...,  98,  98,  94]],
#
#          [[ 10,   8,  10, ...,  16,   6,  24],
#           [ 12,  16,   8, ...,   6,   8,  12],
#           [  8,   6,  12, ...,  12,   4,  12],
#           ...,
#           [ 56,  56, 100, ...,  77,  75,  75],
#           [ 50,  64,  73, ..., 113,  79,  62],
#           [ 69,  85,  50, ..., 125,  71,  90]],
#
#          [[ 12,   4,  10, ...,   8,   8,  12],
#           [  4,  10,   6, ...,  10,  14,  16],
#           [  4,   6,   4, ...,  16,  16,  16],
#           ...,
#           [ 54,  73,  85, ...,  73,  75,  73],
#           [ 73,  73,  71, ...,  90,  96,  64],
#           [ 62,  67,  90, ...,  79,  85,  62]],
#
#          ...,
#
# ...

# %%
stack[:,:,10]
# Out:
# Image3D([[16,  8, 12, ..., 98, 81, 94],
#          [24, 12, 12, ..., 75, 62, 90],
#          [12, 16, 16, ..., 73, 64, 62],
#          ...,
#          [ 8,  6, 14, ..., 16, 14,  8],
#          [12,  8, 10, ...,  4, 12, 12],
#          [18,  4, 10, ...,  8, 10, 16]], dtype=uint8)

# %%
stack.metadata.PhysicalSizeX
# Out:
# '0.1916403326810176'

# %%
stack.save('mynuclei.tif')
